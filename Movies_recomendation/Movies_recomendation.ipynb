# %%
import pandas as pd
import sklearn
import string
import nltk
nltk.download('stopwords')
from nltk.stem.porter import *
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# Jupyter notebook created for movies recomendation based on tags.
# The first step is to load data set and check tags appearance.

# %%
df = pd.read_csv("/content/tags.csv.zip")

# %% [markdown]
# The most popular is sci-fi tags.

# %%
df['tag'].value_counts()
# Out:
# sci-fi              8330
# atmospheric         6516
# action              5907
# comedy              5702
# surreal             5326
#                     ...
# teen sleuth            1
# evil twins             1
# paternity test         1
# QVC                    1
# cornetto triolgy       1
# Name: tag, Length: 73050, dtype: int64

# %%
translator = str.maketrans('','', string.punctuation)
tags = list(df['tag'].str.lower().unique())
tags = [str(t).translate(translator) for t in tags]

df[df['tag'].map(lambda x: type(x)) != str]
# Out:
#         userId  movieId  tag   timestamp
# 860902  121710    33826  NaN  1221450908
# 976395  141727      123  NaN  1199450867
# 976396  141727      346  NaN  1199451946
# 976400  141727     1184  NaN  1199452261
# 976407  141727     1785  NaN  1199452006
# 976408  141727     2194  NaN  1199450677
# 976410  141727     2691  NaN  1199451002
# 976418  141727     4103  NaN  1199451920
# 976420  141727     4473  NaN  1199451040
# 976422  141727     4616  NaN  1199452441
# 976438  141727     7624  NaN  1199452266
# 976444  141727     8898  NaN  1199450757
# 976451  141727    32460  NaN  1199450901
# 976453  141727    33826  NaN  1199450703
# 976458  141727    36537  NaN  1199450736
# 976459  141727    55805  NaN  1199450941

# %% [markdown]
# #Stemming
# Used to reduce number of tags by removal of conjugated forms.

# %%
def transform(vector):
  t = str(vector)
  t = t.translate(translator)
  return stemmer.stem(t)

# %%
stemmer = PorterStemmer()
stags = [stemmer.stem(t) for t in tags]
stags = set(stags)

# %% [markdown]
# Tags which appears less then 200 times are droped.

# %%
df['tag'] = df['tag'].str.lower()
df['ttag'] = df['tag'].map(transform)
c = df['ttag'].value_counts()
c = set(c[c>200].index)
df = df[df['ttag'].isin(c)]
filtered_df = df[df['ttag'].isin(c)]

# %% [markdown]
# #Creation of the movies' and users' profiles

# %% [markdown]
# ##Movie profile

# %%
movies = filtered_df[['movieId', 'userId', 'ttag']].groupby('movieId')['ttag'].apply(set)
movies = filtered_df.join(movies, on='movieId', rsuffix='_g')
movies = movies.drop_duplicates("movieId")
movies_profile = movies[["movieId", 'ttag_g']]
print(movies_profile)
# Out:
#          movieId                                             ttag_g
# 0            260  {intellig, betamax, horror, feelgood, western,...
# 2           1732  {violenc, humor, funni, marijuana, atmospher, ...
# 4           7569  {70mm, assassin, so bad its good, submarin, sp...
# 6         115569  {car chas, intellig, creepi, satir, geniu, dar...
# 7         115713  {twist end, violenc, intellig, creepi, dystopi...
# ...          ...                                                ...
# 1092704   163458                                            {india}
# 1092707   163460                                            {india}
# 1092710   163462                                            {india}
# 1092801   167466                                     {music, drama}
# 1093357   189169                          {comedi, disabl, robberi}
#
# [38832 rows x 2 columns]

# %% [markdown]
# ##User profile

# %%
users = filtered_df[['movieId', 'userId', 'ttag']].groupby('userId')['ttag'].apply(set)
users = filtered_df.join(users, on='userId', rsuffix='_u')
users_profile = users.drop_duplicates('userId')
users_profile = users_profile[['userId', 'ttag_u']]
print(users_profile)
# Out:
#          userId                                             ttag_u
# 0             3                                   {scifi, classic}
# 2             4  {artificial intellig, music, tens, philosoph, ...
# 16           19  {adventur, anim, postapocalypt, fantasi, hayao...
# 24           43                                   {clint eastwood}
# 25           68                                            {music}
# ...         ...                                                ...
# 1093336  162462                                     {space, scifi}
# 1093344  162492                              {epic, classic scifi}
# 1093346  162495                         {nudity full frontal  not}
# 1093348  162501                                            {crime}
# 1093357  162534                          {comedi, disabl, robberi}
#
# [12646 rows x 2 columns]

# %% [markdown]
# #Recomendation
# To recomend movies Jaccard Index is used.

# %%
def jaccard(A, B):
  return len(A.intersection(B)) / len(A.union(B))

# %% [markdown]
# ## movie recomendation fo every user

# %%
for index, user_row in users_profile.iterrows():
  for index, movie_row in movies_profile.iterrows():
    if jaccard(user_row['ttag_u'], movie_row['ttag_g']) >= 0.5:
      print(user_row['userId'], user_row['ttag_u'])
      print(movie_row['movieId'], movie_row['ttag_g'])
      print("======================")
# Out:
# Streaming output truncated to the last 5000 lines.
# 58434 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 64548 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 68597 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 69670 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 74064 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 78698 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 78838 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 80233 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 81195 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 82308 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 83227 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 91694 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 95650 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 95896 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 95975 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 97853 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 98004 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 98475 {'crime'}
# ======================
# 6912 {'suspens', 'crime'}
# 100906 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 106401 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 110975 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 116130 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 116243 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 116943 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 117346 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 117354 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 117472 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 117632 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 117740 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 118974 {'crime'}
# ======================
# 6912 {'suspens', 'crime'}
# 121269 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 122234 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 124496 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 124781 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 124975 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 128766 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 128770 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 128884 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 129522 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 129646 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 130784 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 130912 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 131380 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 132056 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 132124 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 132346 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 133604 {'crime'}
# ======================
# 6912 {'suspens', 'crime'}
# 134260 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 137331 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 137415 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 137974 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 139159 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 139283 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 139580 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 140930 {'crime'}
# ======================
# 6912 {'suspens', 'crime'}
# 140938 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 141670 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 142418 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 143115 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 143406 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 144020 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 144029 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 144332 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 144414 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 144768 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 145152 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 145228 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 145290 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 145330 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 149034 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 150196 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 154128 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 155096 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 155137 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 156712 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 156900 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 159055 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 160436 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 161530 {'crime'}
# ======================
# 6912 {'suspens', 'crime'}
# 161552 {'crime'}
# ======================
# 6912 {'suspens', 'crime'}
# 161554 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 161882 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 162256 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 167838 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 174991 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 175057 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 175553 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 176005 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 176583 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 176633 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 177901 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 178641 {'crime'}
# ======================
# 6912 {'suspens', 'crime'}
# 178725 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 180675 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 180827 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 184805 {'crime'}
# ======================
# 6912 {'suspens', 'crime'}
# 184853 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 185639 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 188649 {'crime'}
# ======================
# 6912 {'suspens', 'crime'}
# 188843 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 95595 {'suspens'}
# ======================
# 6912 {'suspens', 'crime'}
# 110503 {'crime'}
# ======================
# 6912 {'suspens', 'crime'}
# 26167 {'crime'}
# ======================
# 6912 {'suspens', 'crime'}
# 205475 {'crime'}
# ======================
# 6912 {'suspens', 'crime'}
# 195091 {'crime'}
# ======================
# 6912 {'suspens', 'crime'}
# 164947 {'crime'}
# ======================
# 6921 {'comput'}
# 73710 {'comput', 'technolog'}
# ======================
# 6921 {'comput'}
# 104224 {'comput', 'hacker'}
# ======================
# 6921 {'comput'}
# 140860 {'comput', 'hacker'}
# ======================
# 6921 {'comput'}
# 140862 {'comput', 'hacker'}
# ======================
# 6921 {'comput'}
# 60702 {'comput', 'sequel'}
# ======================
# 6921 {'comput'}
# 81085 {'comput', 'postapocalypt'}
# ======================
# 6921 {'comput'}
# 122533 {'comput', 'drug'}
# ======================
# 6921 {'comput'}
# 141357 {'comput', 'futur'}
# ======================
# 6921 {'comput'}
# 161185 {'comput', 'futur'}
# ======================
# 6921 {'comput'}
# 172367 {'comput'}
# ======================
# 6921 {'comput'}
# 185835 {'comput', 'computer anim'}
# ======================
# 6921 {'comput'}
# 157148 {'comput'}
# ======================
# 6921 {'comput'}
# 190253 {'comput', 'ridley scott'}
# ======================
# 6939 {'touch'}
# 6760 {'touch', 'r'}
# ======================
# 6939 {'touch'}
# 204158 {'touch'}
# ======================
# 6939 {'touch'}
# 536 {'touch', 'christma'}
# ======================
# 6950 {'french'}
# 169390 {'french', 'polic'}
# ======================
# 6950 {'french'}
# 26691 {'french', 'london england'}
# ======================
# 6950 {'french'}
# 42629 {'french', 'dvdvideo'}
# ======================
# 6950 {'french'}
# 86314 {'french', 'bdr'}
# ======================
# 6950 {'french'}
# 117716 {'french'}
# ======================
# 6950 {'french'}
# 122841 {'french', 'spi'}
# ======================
# 6950 {'french'}
# 124310 {'french', 'woman director'}
# ======================
# 6950 {'french'}
# 130241 {'french'}
# ======================
# 6950 {'french'}
# 136906 {'french', 'woman director'}
# ======================
# 6950 {'french'}
# 149757 {'french'}
# ======================
# 6950 {'french'}
# 151082 {'french'}
# ======================
# 6950 {'french'}
# 163999 {'french', 'haunted hous'}
# ======================
# 6950 {'french'}
# 187075 {'nerd', 'french'}
# ======================
# 6950 {'french'}
# 170601 {'comedi', 'french'}
# ======================
# 6950 {'french'}
# 147142 {'french'}
# ======================
# 6950 {'french'}
# 96943 {'french', 'nudity topless'}
# ======================
# 6950 {'french'}
# 142360 {'french'}
# ======================
# 6950 {'french'}
# 68886 {'french', 'marriag'}
# ======================
# 6950 {'french'}
# 117334 {'french'}
# ======================
# 6950 {'french'}
# 126777 {'french', 'lesbian'}
# ======================
# 6950 {'french'}
# 144964 {'french'}
# ======================
# 6950 {'french'}
# 190105 {'comedi', 'french'}
# ======================
# 6950 {'french'}
# 86922 {'comedi', 'french'}
# ======================
# 6950 {'french'}
# 73713 {'french', 'humor'}
# ======================
# 6950 {'french'}
# 207638 {'french', 'surreal'}
# ======================
# 6950 {'french'}
# 70978 {'witti', 'french'}
# ======================
# 6950 {'french'}
# 173599 {'foreign', 'french'}
# ======================
# 6950 {'french'}
# 179115 {'french', 'thriller'}
# ======================
# 6950 {'french'}
# 147603 {'french'}
# ======================
# 6950 {'french'}
# 188023 {'comedi', 'french'}
# ======================
# 6950 {'french'}
# 147398 {'terror', 'french'}
# ======================
# 6950 {'french'}
# 26417 {'french', 'franc'}
# ======================
# 6950 {'french'}
# 65304 {'french', 'franc'}
# ======================
# 6950 {'french'}
# 97699 {'french', 'franc'}
# ======================
# 6950 {'french'}
# 98509 {'french', 'franc'}
# ======================
# 6950 {'french'}
# 98985 {'french', 'franc'}
# ======================
# 6950 {'french'}
# 108050 {'french'}
# ======================
# 6950 {'french'}
# 108237 {'french', 'franc'}
# ======================
# 6950 {'french'}
# 108811 {'french', 'franc'}
# ======================
# 6950 {'french'}
# 108901 {'french', 'franc'}
# ======================
# 6950 {'french'}
# 109010 {'french', 'franc'}
# ======================
# 6950 {'french'}
# 109159 {'french', 'franc'}
# ======================
# 6950 {'french'}
# 109468 {'french', 'franc'}
# ======================
# 6950 {'french'}
# 110063 {'french', 'franc'}
# ======================
# 6950 {'french'}
# 110108 {'french', 'franc'}
# ======================
# 6950 {'french'}
# 110276 {'french', 'franc'}
# ======================
# 6950 {'french'}
# 110278 {'french', 'franc'}
# ======================
# 6950 {'french'}
# 110314 {'french', 'franc'}
# ======================
# 6950 {'french'}
# 110377 {'french', 'franc'}
# ======================
# 6950 {'french'}
# 141446 {'french'}
# ======================
# 6950 {'french'}
# 142558 {'french'}
# ======================
# 6950 {'french'}
# 6081 {'french', 'polic'}
# ======================
# 6950 {'french'}
# 168412 {'comedi', 'french'}
# ======================
# 6950 {'french'}
# 193407 {'french'}
# ======================
# 6950 {'french'}
# 144056 {'french'}
# ======================
# 6950 {'french'}
# 174629 {'comedi', 'french'}
# ======================
# 6950 {'french'}
# 126929 {'french'}
# ======================
# 6972 {'commun', 'histor', 'long', 'revolut'}
# 71989 {'commun', 'revolut'}
# ======================
# 7028 {'clint eastwood'}
# 89620 {'clint eastwood', 'antholog'}
# ======================
# 7055 {'inspir'}
# 50703 {'inspir', 'bad scienc'}
# ======================
# 7055 {'inspir'}
# 104910 {'inspir'}
# ======================
# 7055 {'inspir'}
# 132902 {'inspir', 'femin'}
# ======================
# 7055 {'inspir'}
# 144064 {'inspir', 'standup comedi'}
# ======================
# 7055 {'inspir'}
# 153754 {'inspir', 'woman director'}
# ======================
# 7055 {'inspir'}
# 161165 {'inspir', 'box'}
# ======================
# 7055 {'inspir'}
# 161786 {'inspir'}
# ======================
# 7055 {'inspir'}
# 168428 {'inspir', 'romanc'}
# ======================
# 7055 {'inspir'}
# 177655 {'inspir', 'new york'}
# ======================
# 7055 {'inspir'}
# 180121 {'inspir', 'drama'}
# ======================
# 7055 {'inspir'}
# 184409 {'inspir', 'uplift'}
# ======================
# 7055 {'inspir'}
# 154935 {'inspir', 'underdog'}
# ======================
# 7055 {'inspir'}
# 197177 {'inspir', 'johnny depp'}
# ======================
# 7055 {'inspir'}
# 154051 {'space', 'inspir'}
# ======================
# 7055 {'inspir'}
# 151357 {'inspir', 'emot'}
# ======================
# 7055 {'inspir'}
# 92083 {'inspir', 'medit'}
# ======================
# 7055 {'inspir'}
# 134855 {'inspir', 'civil war'}
# ======================
# 7055 {'inspir'}
# 87984 {'inspir'}
# ======================
# 7055 {'inspir'}
# 199580 {'inspir'}
# ======================
# 7055 {'inspir'}
# 198883 {'inspir', 'educ'}
# ======================
# 7055 {'inspir'}
# 196067 {'inspir', 'documentari'}
# ======================
# 7055 {'inspir'}
# 100044 {'inspir', 'educ'}
# ======================
# 7055 {'inspir'}
# 46919 {'based on a true stori', 'inspir'}
# ======================
# 7055 {'inspir'}
# 151599 {'inspir', 'documentari'}
# ======================
# 7055 {'inspir'}
# 86412 {'inspir'}
# ======================
# 7055 {'inspir'}
# 190189 {'inspir'}
# ======================
# 7055 {'inspir'}
# 189693 {'inspir', 'music'}
# ======================
# 7055 {'inspir'}
# 64418 {'inspir', 'racism'}
# ======================
# 7055 {'inspir'}
# 151384 {'inspir', 'educ'}
# ======================
# 7055 {'inspir'}
# 184923 {'inspir'}
# ======================
# 7055 {'inspir'}
# 81000 {'inspir', 'train'}
# ======================
# 7055 {'inspir'}
# 146104 {'inspir'}
# ======================
# 7055 {'inspir'}
# 196341 {'comedi', 'inspir'}
# ======================
# 7061 {'action'}
# 204 {'train', 'action'}
# ======================
# 7061 {'action'}
# 2887 {'comedi', 'action'}
# ======================
# 7061 {'action'}
# 175505 {'action'}
# ======================
# 7061 {'action'}
# 191469 {'adventur', 'action'}
# ======================
# 7061 {'action'}
# 194787 {'famili', 'action'}
# ======================
# 7061 {'action'}
# 33148 {'action'}
# ======================
# 7061 {'action'}
# 76130 {'action', 'hostag'}
# ======================
# 7061 {'action'}
# 109576 {'comedi', 'action'}
# ======================
# 7061 {'action'}
# 121257 {'experi', 'action'}
# ======================
# 7061 {'action'}
# 149942 {'action'}
# ======================
# 7061 {'action'}
# 170899 {'action'}
# ======================
# 7061 {'action'}
# 184115 {'noir', 'action'}
# ======================
# 7061 {'action'}
# 187479 {'spi', 'action'}
# ======================
# 7061 {'action'}
# 187877 {'action', 'music'}
# ======================
# 7061 {'action'}
# 187883 {'kidnap', 'action'}
# ======================
# 7061 {'action'}
# 8908 {'joaquin phoenix', 'action'}
# ======================
# 7061 {'action'}
# 154757 {'western', 'action'}
# ======================
# 7061 {'action'}
# 161266 {'action'}
# ======================
# 7061 {'action'}
# 91634 {'militari', 'action'}
# ======================
# 7061 {'action'}
# 85298 {'action'}
# ======================
# 7061 {'action'}
# 71460 {'easily confused with other movies titl', 'action'}
# ======================
# 7061 {'action'}
# 153925 {'action'}
# ======================
# 7061 {'action'}
# 155092 {'action'}
# ======================
# 7061 {'action'}
# 157551 {'action'}
# ======================
# 7061 {'action'}
# 157553 {'action'}
# ======================
# 7061 {'action'}
# 158286 {'action'}
# ======================
# 7061 {'action'}
# 158288 {'action'}
# ======================
# 7061 {'action'}
# 174111 {'action'}
# ======================
# 7061 {'action'}
# 179499 {'comedi', 'action'}
# ======================
# 7061 {'action'}
# 183241 {'action'}
# ======================
# 7061 {'action'}
# 187453 {'comedi', 'action'}
# ======================
# 7061 {'action'}
# 187827 {'comedi', 'action'}
# ======================
# 7061 {'action'}
# 187829 {'comedi', 'action'}
# ======================
# 7061 {'action'}
# 187831 {'comedi', 'action'}
# ======================
# 7061 {'action'}
# 187833 {'comedi', 'action'}
# ======================
# 7061 {'action'}
# 187835 {'action'}
# ======================
# 7061 {'action'}
# 187841 {'comedi', 'action'}
# ======================
# 7061 {'action'}
# 187845 {'action'}
# ======================
# 7061 {'action'}
# 187863 {'comedi', 'action'}
# ======================
# 7061 {'action'}
# 187879 {'action'}
# ======================
# 7061 {'action'}
# 187881 {'action'}
# ======================
# 7061 {'action'}
# 187891 {'action'}
# ======================
# 7061 {'action'}
# 187897 {'action'}
# ======================
# 7061 {'action'}
# 187901 {'action'}
# ======================
# 7061 {'action'}
# 187903 {'action', 'drama'}
# ======================
# 7061 {'action'}
# 187907 {'thriller', 'action'}
# ======================
# 7061 {'action'}
# 187913 {'comedi', 'action'}
# ======================
# 7061 {'action'}
# 187917 {'action'}
# ======================
# 7061 {'action'}
# 187923 {'action'}
# ======================
# 7061 {'action'}
# 187927 {'comedi', 'action'}
# ======================
# 7061 {'action'}
# 187929 {'action'}
# ======================
# 7061 {'action'}
# 191695 {'thriller', 'action'}
# ======================
# 7061 {'action'}
# 184119 {'action', 'drama'}
# ======================
# 7061 {'action'}
# 190641 {'native american', 'action'}
# ======================
# 7061 {'action'}
# 190643 {'native american', 'action'}
# ======================
# 7061 {'action'}
# 190645 {'native american', 'action'}
# ======================
# 7061 {'action'}
# 185569 {'action', 'drama'}
# ======================
# 7087 {'adventur', 'scifi', 'action'}
# 191469 {'adventur', 'action'}
# ======================
# 7087 {'adventur', 'scifi', 'action'}
# 165185 {'adventur', 'b movi', 'scifi', 'space', 'nuditi', 'action'}
# ======================
# 7087 {'adventur', 'scifi', 'action'}
# 167430 {'scifi', 'suicide attempt', 'action'}
# ======================
# 7087 {'adventur', 'scifi', 'action'}
# 184289 {'adventur', 'anim', 'action'}
# ======================
# 7087 {'adventur', 'scifi', 'action'}
# 183077 {'adventur', 'scifi', 'horror'}
# ======================
# 7087 {'adventur', 'scifi', 'action'}
# 98695 {'adventur', 'scifi'}
# ======================
# 7087 {'adventur', 'scifi', 'action'}
# 69524 {'adventur', 'humor', 'action'}
# ======================
# 7127 {'morgan freeman'}
# 1752 {'morgan freeman'}
# ======================
# 7256 {'submarin'}
# 135 {'submarin', 'hilari'}
# ======================
# 7256 {'submarin'}
# 8686 {'submarin', 'less than 300 r'}
# ======================
# 7256 {'submarin'}
# 26042 {'bdr', 'submarin'}
# ======================
# 7256 {'submarin'}
# 30695 {'world war ii', 'submarin'}
# ======================
# 7256 {'submarin'}
# 79081 {'submarin'}
# ======================
# 7256 {'submarin'}
# 97884 {'world war ii', 'submarin'}
# ======================
# 7256 {'submarin'}
# 101097 {'cold war', 'submarin'}
# ======================
# 7256 {'submarin'}
# 104294 {'bdr', 'submarin'}
# ======================
# 7256 {'submarin'}
# 105974 {'bdr', 'submarin'}
# ======================
# 7256 {'submarin'}
# 114188 {'submarin'}
# ======================
# 7256 {'submarin'}
# 121875 {'submarin'}
# ======================
# 7256 {'submarin'}
# 127642 {'submarin', 'camp'}
# ======================
# 7256 {'submarin'}
# 133499 {'heist', 'submarin'}
# ======================
# 7256 {'submarin'}
# 138236 {'submarin'}
# ======================
# 7256 {'submarin'}
# 138754 {'submarin', 'monster'}
# ======================
# 7256 {'submarin'}
# 140499 {'submarin'}
# ======================
# 7256 {'submarin'}
# 144818 {'submarin'}
# ======================
# 7256 {'submarin'}
# 152202 {'submarin'}
# ======================
# 7256 {'submarin'}
# 186367 {'submarin'}
# ======================
# 7256 {'submarin'}
# 195929 {'submarin'}
# ======================
# 7256 {'submarin'}
# 152471 {'submarin'}
# ======================
# 7256 {'submarin'}
# 110568 {'submarin', 'great end'}
# ======================
# 7259 {'documentari', 'anim'}
# 190751 {'heartwarm', 'documentari', 'dog', 'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 158739 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 158749 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 158753 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 189137 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 190339 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 190481 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 107304 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 146427 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 3226 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 68831 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 68959 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 80083 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 83535 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 92658 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 95165 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 95182 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 96897 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 104266 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 108056 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 111230 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 111626 {'documentari', 'anim', 'friendship'}
# ======================
# 7259 {'documentari', 'anim'}
# 114078 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 117638 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 124869 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 129921 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 134668 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 136333 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 137859 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 137863 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 138944 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 140365 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 140707 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 140773 {'documentari', 'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 143511 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 143892 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 144198 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 144296 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 144712 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 148384 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 149723 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 150385 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 150387 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 150894 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 156045 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 157073 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 157729 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 157757 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 157765 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 157795 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 157809 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 157811 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 157819 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 162970 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 162972 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 162974 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 162976 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 162978 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 162980 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 163767 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 164262 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 165757 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 168582 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 168982 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 169520 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 171021 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 172653 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 173337 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 174515 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 174819 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 175477 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 176461 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 177113 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 178709 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 178729 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 179233 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 180997 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 182857 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 183683 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 183845 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 183967 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 183987 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 184183 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 184715 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 185151 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 186221 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 186823 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 186867 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 187049 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 188139 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 189109 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 443 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 72169 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 129036 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 129530 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 197069 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 100169 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 133285 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 133439 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 117857 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 175969 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 166369 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 164513 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 166922 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 190527 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 151701 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 113244 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 165877 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 186813 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 148468 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 163072 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 163112 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 163386 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 197691 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 121407 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 144174 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 96563 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 163925 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 65435 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 204802 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 202231 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 147841 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 76866 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 183933 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 170669 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 187145 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 54354 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 189255 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 138966 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 200704 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 194833 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 109151 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 189889 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 193533 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 173711 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 121029 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 82280 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 6945 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 134383 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 148470 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 157077 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 157079 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 157196 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 157204 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 129389 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 140581 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 203138 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 204490 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 88897 {'documentari', 'anim', 'prostitut'}
# ======================
# 7259 {'documentari', 'anim'}
# 187847 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 164039 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 116899 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 133149 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 133159 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 101904 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 108403 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 139775 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 172879 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 172881 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 189195 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 189353 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 158852 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 158858 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 158862 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 177251 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 187561 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 107713 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 206010 {'documentari', 'anim', 'dog'}
# ======================
# 7259 {'documentari', 'anim'}
# 103275 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 201757 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 146876 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 97757 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 4719 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 186429 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 142679 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 174541 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 193587 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 119782 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 136190 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 142663 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 208293 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 165963 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 182349 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 63828 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 168870 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 176757 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 166880 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 165003 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 194612 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 180565 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 167328 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 141412 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 91597 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 99820 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 99822 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 90497 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 140557 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 204722 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 59655 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 136521 {'documentari'}
# ======================
# 7259 {'documentari', 'anim'}
# 139128 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 151513 {'anim'}
# ======================
# 7259 {'documentari', 'anim'}
# 195245 {'anim'}
# ======================
# 7290 {'black comedi', 'british comedi', 'zombi'}
# 2552 {'black comedi', 'irrever', 'zombi'}
# ======================
# 7293 {'scifi', 'action'}
# 6264 {'bad scienc', 'unrealist', 'scifi', 'action'}
# ======================
# 7293 {'scifi', 'action'}
# 175505 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 33148 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 131050 {'scifi', 'space travel', 'action', 'alien'}
# ======================
# 7293 {'scifi', 'action'}
# 149942 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 167430 {'scifi', 'suicide attempt', 'action'}
# ======================
# 7293 {'scifi', 'action'}
# 170899 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 126579 {'scifi'}
# ======================
# 7293 {'scifi', 'action'}
# 161266 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 85298 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 153925 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 155092 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 157551 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 157553 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 158286 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 158288 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 174111 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 183241 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 187835 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 187845 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 187879 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 187881 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 187891 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 187897 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 187901 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 187917 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 187923 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 187929 {'action'}
# ======================
# 7293 {'scifi', 'action'}
# 195199 {'short film', 'short', 'scifi', 'action'}
# ======================
# 7293 {'scifi', 'action'}
# 195741 {'short film', 'short', 'scifi', 'action'}
# ======================
# 7293 {'scifi', 'action'}
# 173633 {'horror', 'scifi', 'mysteri', 'action'}
# ======================
# 7341 {'coming of ag'}
# 219 {'easily confused with other movies titl', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 82635 {'divorc', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 59976 {'criterion', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 576 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 4048 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 5685 {'coming of ag', 'woman director'}
# ======================
# 7341 {'coming of ag'}
# 81755 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 84096 {'independent film', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 90019 {'nudity topless', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 97615 {'coming of ag', 'woman director'}
# ======================
# 7341 {'coming of ag'}
# 98693 {'teenag', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 99744 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 103237 {'coming of ag', 'woman director'}
# ======================
# 7341 {'coming of ag'}
# 103910 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 109485 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 117551 {'coming of ag', 'woman director'}
# ======================
# 7341 {'coming of ag'}
# 117557 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 118882 {'independent film', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 119814 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 121421 {'teenag', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 121537 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 132674 {'coming of ag', 'road movi'}
# ======================
# 7341 {'coming of ag'}
# 133739 {'long', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 135502 {'coming of ag', 'travel'}
# ======================
# 7341 {'coming of ag'}
# 144750 {'mathemat', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 144850 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 150716 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 153600 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 153810 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 155982 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 159353 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 159367 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 161092 {'coming of ag', 'woman director'}
# ======================
# 7341 {'coming of ag'}
# 162060 {'photographi', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 164322 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 167606 {'coming of ag', 'woman director'}
# ======================
# 7341 {'coming of ag'}
# 168914 {'coming of ag', 'drama'}
# ======================
# 7341 {'coming of ag'}
# 174367 {'coming of ag', 'apocalyps'}
# ======================
# 7341 {'coming of ag'}
# 174833 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 175123 {'culture clash', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 175451 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 178855 {'itali', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 180731 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 183477 {'independent film', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 184197 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 185857 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 186259 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 186445 {'coming of ag', 'woman director'}
# ======================
# 7341 {'coming of ag'}
# 186561 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 186939 {'coming of ag', '1970'}
# ======================
# 7341 {'coming of ag'}
# 188619 {'pregnanc', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 189267 {'coming of ag', 'woman director'}
# ======================
# 7341 {'coming of ag'}
# 109181 {'writer', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 147402 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 121180 {'nerd', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 163995 {'adventur', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 189049 {'coming of ag', 'high school'}
# ======================
# 7341 {'coming of ag'}
# 137299 {'coming of ag', 'natur'}
# ======================
# 7341 {'coming of ag'}
# 113751 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 192565 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 177157 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 133337 {'coming of ag', 'sweet'}
# ======================
# 7341 {'coming of ag'}
# 168762 {'famili', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 178077 {'australia', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 114550 {'werewolv', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 49037 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 113227 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 101350 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 88053 {'friendship', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 88925 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 99364 {'humor', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 104604 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 117889 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 154364 {'footbal', 'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 76808 {'coming of ag'}
# ======================
# 7341 {'coming of ag'}
# 188191 {'coming of ag'}
# ======================
# 7344 {'space', 'fantasi'}
# 96516 {'space'}
# ======================
# 7344 {'space', 'fantasi'}
# 122687 {'space'}
# ======================
# 7344 {'space', 'fantasi'}
# 125323 {'fantasi'}
# ======================
# 7344 {'space', 'fantasi'}
# 132364 {'space'}
# ======================
# 7344 {'space', 'fantasi'}
# 143537 {'fantasi'}
# ======================
# 7344 {'space', 'fantasi'}
# 144148 {'space'}
# ======================
# 7344 {'space', 'fantasi'}
# 160996 {'space'}
# ======================
# 7344 {'space', 'fantasi'}
# 166038 {'space'}
# ======================
# 7344 {'space', 'fantasi'}
# 168278 {'space'}
# ======================
# 7344 {'space', 'fantasi'}
# 174039 {'fantasi'}
# ======================
# 7344 {'space', 'fantasi'}
# 177729 {'fantasi'}
# ======================
# 7344 {'space', 'fantasi'}
# 105985 {'space'}
# ======================
# 7344 {'space', 'fantasi'}
# 113739 {'space'}
# ======================
# 7344 {'space', 'fantasi'}
# 125473 {'space'}
# ======================
# 7344 {'space', 'fantasi'}
# 169616 {'space'}
# ======================
# 7344 {'space', 'fantasi'}
# 7988 {'space'}
# ======================
# 7344 {'space', 'fantasi'}
# 84140 {'space'}
# ======================
# 7344 {'space', 'fantasi'}
# 135965 {'fantasi'}
# ======================
# 7344 {'space', 'fantasi'}
# 100509 {'fantasi'}
# ======================
# 7344 {'space', 'fantasi'}
# 179245 {'fantasi'}
# ======================
# 7370 {'polit'}
# 157 {'conspiraci', 'polit'}
# ======================
# 7370 {'polit'}
# 206727 {'polit'}
# ======================
# 7370 {'polit'}
# 3120 {'polit', 'greed'}
# ======================
# 7370 {'polit'}
# 3958 {'polit'}
# ======================
# 7370 {'polit'}
# 4300 {'perrot librari', 'polit'}
# ======================
# 7370 {'polit'}
# 5336 {'revolut', 'polit'}
# ======================
# 7370 {'polit'}
# 8960 {'polit', 'magnolia pictur'}
# ======================
# 7370 {'polit'}
# 26034 {'bdr', 'polit'}
# ======================
# 7370 {'polit'}
# 27718 {'histori', 'polit'}
# ======================
# 7370 {'polit'}
# 49757 {'polit'}
# ======================
# 7370 {'polit'}
# 78759 {'biographi', 'polit'}
# ======================
# 7370 {'polit'}
# 80560 {'polit'}
# ======================
# 7370 {'polit'}
# 84471 {'criterion', 'polit'}
# ======================
# 7370 {'polit'}
# 91268 {'polit', 'ireland'}
# ======================
# 7370 {'polit'}
# 92410 {'polit', 'propaganda'}
# ======================
# 7370 {'polit'}
# 102967 {'bdr', 'polit'}
# ======================
# 7370 {'polit'}
# 103243 {'polit'}
# ======================
# 7370 {'polit'}
# 104673 {'kidnap', 'polit'}
# ======================
# 7370 {'polit'}
# 104726 {'new york c', 'polit'}
# ======================
# 7370 {'polit'}
# 107730 {'polit', 'woman director'}
# ======================
# 7370 {'polit'}
# 108491 {'polit', 'woman director'}
# ======================
# 7370 {'polit'}
# 115233 {'berlin', 'polit'}
# ======================
# 7370 {'polit'}
# 117722 {'short', 'polit'}
# ======================
# 7370 {'polit'}
# 121581 {'polit'}
# ======================
# 7370 {'polit'}
# 123278 {'conspiraci', 'polit'}
# ======================
# 7370 {'polit'}
# 123645 {'polit', '1940'}
# ======================
# 7370 {'polit'}
# 125628 {'polit', 'woman director'}
# ======================
# 7370 {'polit'}
# 125658 {'polit'}
# ======================
# 7370 {'polit'}
# 130896 {'polit'}
# ======================
# 7370 {'polit'}
# 133319 {'scienc', 'polit'}
# ======================
# 7370 {'polit'}
# 134342 {'corrupt', 'polit'}
# ======================
# 7370 {'polit'}
# 134553 {'polit', 'satir'}
# ======================
# 7370 {'polit'}
# 135438 {'polit'}
# ======================
# 7370 {'polit'}
# 136435 {'standup comedi', 'polit'}
# ======================
# 7370 {'polit'}
# 138492 {'polit', 'satir'}
# ======================
# 7370 {'polit'}
# 138620 {'standup comedi', 'polit'}
# ======================
# 7370 {'polit'}
# 139563 {'polit'}
# ======================
# 7370 {'polit'}
# 140659 {'polit'}
# ======================
# 7370 {'polit'}
# 141034 {'racism', 'polit'}
# ======================
# 7370 {'polit'}
# 141472 {'histori', 'polit'}
# ======================
# 7370 {'polit'}
# 143412 {'small town', 'polit'}
# ======================
# 7370 {'polit'}
# 144972 {'short', 'polit'}
# ======================
# 7370 {'polit'}
# 146090 {'polit'}
# ======================
# 7370 {'polit'}
# 146299 {'polit'}
# ======================
# 7370 {'polit'}
# 146948 {'polit', 'satir'}
# ======================
# 7370 {'polit'}
# 148799 {'polit'}
# ======================
# 7370 {'polit'}
# 150619 {'polit'}
# ======================
# 7370 {'polit'}
# 150864 {'polit'}
# ======================
# 7370 {'polit'}
# 151319 {'polit', 'nostalgia'}
# ======================
# 7370 {'polit'}
# 152565 {'seduct', 'polit'}
# ======================
# 7370 {'polit'}
# 154059 {'polit'}
# ======================
# 7370 {'polit'}
# 158109 {'investig', 'polit'}
# ======================
# 7370 {'polit'}
# 159139 {'philosophi', 'polit'}
# ======================
# 7370 {'polit'}
# 161924 {'polit'}
# ======================
# 7370 {'polit'}
# 162200 {'polit'}
# ======================
# 7370 {'polit'}
# 162216 {'hack', 'polit'}
# ======================
# 7370 {'polit'}
# 163036 {'documentari', 'polit'}
# ======================
# 7370 {'polit'}
# 163124 {'polit'}
# ======================
# 7370 {'polit'}
# 163683 {'polit'}
# ======================
# 7370 {'polit'}
# 164399 {'polit', 'polic'}
# ======================
# 7370 {'polit'}
# 164584 {'polit'}
# ======================
# 7370 {'polit'}
# ...
# 8039 {'seen more than onc', 'pari'}
# 71413 {'pari'}
# ======================
# 8039 {'seen more than onc', 'pari'}
# 79775 {'pari'}
# ======================
# 8039 {'seen more than onc', 'pari'}
# 97768 {'pari'}
# ======================
# 8039 {'seen more than onc', 'pari'}
# 98983 {'pari'}
# ======================
# 8039 {'seen more than onc', 'pari'}
# 104809 {'pari'}
# ======================
# 8039 {'seen more than onc', 'pari'}
# 108936 {'pari'}
# ======================
# 8039 {'seen more than onc', 'pari'}
# 111999 {'pari'}
# ======================
# 8039 {'seen more than onc', 'pari'}
# 138766 {'pari'}
# ======================
# 8039 {'seen more than onc', 'pari'}
# 138850 {'pari'}
# ======================
# 8039 {'seen more than onc', 'pari'}
# 141682 {'pari'}
# ======================
# 8039 {'seen more than onc', 'pari'}
# 143870 {'pari'}
# ======================
# 8039 {'seen more than onc', 'pari'}
# 153656 {'pari'}
# ======================
# 8039 {'seen more than onc', 'pari'}
# 156278 {'pari'}
# ======================
# 8039 {'seen more than onc', 'pari'}
# 160348 {'pari'}
# ======================
# 8039 {'seen more than onc', 'pari'}
# 162118 {'pari'}
# ======================
# 8039 {'seen more than onc', 'pari'}
# 188887 {'pari'}
# ======================
# 8039 {'seen more than onc', 'pari'}
# 113630 {'seen more than onc'}
# ======================
# 8039 {'seen more than onc', 'pari'}
# 71453 {'pari'}
# ======================
# 8053 {'ridley scott', 'scifi', 'alien'}
# 133806 {'science fict', 'scifi', 'alien'}
# ======================
# 8053 {'ridley scott', 'scifi', 'alien'}
# 173307 {'horror', 'scifi', 'alien'}
# ======================
# 8081 {'secret', 'family relationship'}
# 1621 {'family relationship'}
# ======================
# 8081 {'secret', 'family relationship'}
# 88652 {'secret'}
# ======================
# 8081 {'secret', 'family relationship'}
# 100717 {'family relationship'}
# ======================
# 8081 {'secret', 'family relationship'}
# 113073 {'secret'}
# ======================
# 8081 {'secret', 'family relationship'}
# 123522 {'family relationship'}
# ======================
# 8081 {'secret', 'family relationship'}
# 125409 {'family relationship'}
# ======================
# 8081 {'secret', 'family relationship'}
# 126335 {'family relationship'}
# ======================
# 8081 {'secret', 'family relationship'}
# 129380 {'family relationship'}
# ======================
# 8081 {'secret', 'family relationship'}
# 130093 {'family relationship'}
# ======================
# 8081 {'secret', 'family relationship'}
# 130132 {'family relationship'}
# ======================
# 8081 {'secret', 'family relationship'}
# 139799 {'secret'}
# ======================
# 8081 {'secret', 'family relationship'}
# 140771 {'family relationship'}
# ======================
# 8081 {'secret', 'family relationship'}
# 151589 {'family relationship'}
# ======================
# 8081 {'secret', 'family relationship'}
# 151953 {'family relationship'}
# ======================
# 8081 {'secret', 'family relationship'}
# 153919 {'family relationship'}
# ======================
# 8081 {'secret', 'family relationship'}
# 155788 {'secret'}
# ======================
# 8081 {'secret', 'family relationship'}
# 157017 {'family relationship'}
# ======================
# 8081 {'secret', 'family relationship'}
# 158573 {'family relationship'}
# ======================
# 8081 {'secret', 'family relationship'}
# 167786 {'secret'}
# ======================
# 8081 {'secret', 'family relationship'}
# 171385 {'family relationship'}
# ======================
# 8081 {'secret', 'family relationship'}
# 172259 {'family relationship'}
# ======================
# 8081 {'secret', 'family relationship'}
# 173917 {'family relationship'}
# ======================
# 8081 {'secret', 'family relationship'}
# 175073 {'secret'}
# ======================
# 8081 {'secret', 'family relationship'}
# 175617 {'family relationship'}
# ======================
# 8081 {'secret', 'family relationship'}
# 208367 {'family relationship'}
# ======================
# 8081 {'secret', 'family relationship'}
# 48895 {'secret'}
# ======================
# 8084 {'twist end', 'scifi', 'intellig', 'parallel univers', 'psycholog', 'time travel'}
# 183593 {'scifi', 'time travel', 'parallel univers'}
# ======================
# 8113 {'drama'}
# 190317 {'drama'}
# ======================
# 8113 {'drama'}
# 143410 {'war', 'drama'}
# ======================
# 8113 {'drama'}
# 155471 {'drama', 'crime'}
# ======================
# 8113 {'drama'}
# 161584 {'romanc', 'drama'}
# ======================
# 8113 {'drama'}
# 188691 {'marriag', 'drama'}
# ======================
# 8113 {'drama'}
# 189239 {'tv movi', 'drama'}
# ======================
# 8113 {'drama'}
# 199476 {'netflix', 'drama'}
# ======================
# 8113 {'drama'}
# 200324 {'music', 'drama'}
# ======================
# 8113 {'drama'}
# 133 {'new york', 'drama'}
# ======================
# 8113 {'drama'}
# 1825 {'stripper', 'drama'}
# ======================
# 8113 {'drama'}
# 2546 {'kidnap', 'drama'}
# ======================
# 8113 {'drama'}
# 7295 {'magnolia pictur', 'drama'}
# ======================
# 8113 {'drama'}
# 26784 {'lawyer', 'drama'}
# ======================
# 8113 {'drama'}
# 32773 {'famili', 'drama'}
# ======================
# 8113 {'drama'}
# 34226 {'german', 'drama'}
# ======================
# 8113 {'drama'}
# 34464 {'romanc', 'drama'}
# ======================
# 8113 {'drama'}
# 51689 {'love', 'drama'}
# ======================
# 8113 {'drama'}
# 52858 {'sport', 'drama'}
# ======================
# 8113 {'drama'}
# 64327 {'1930', 'drama'}
# ======================
# 8113 {'drama'}
# 67233 {'comedi', 'drama'}
# ======================
# 8113 {'drama'}
# 72391 {'music', 'drama'}
# ======================
# 8113 {'drama'}
# 78559 {'famili', 'drama'}
# ======================
# 8113 {'drama'}
# 80744 {'japanes', 'drama'}
# ======================
# 8113 {'drama'}
# 85012 {'classic', 'drama'}
# ======================
# 8113 {'drama'}
# 88028 {'drama'}
# ======================
# 8113 {'drama'}
# 88419 {'dvdram', 'drama'}
# ======================
# 8113 {'drama'}
# 88855 {'drama'}
# ======================
# 8113 {'drama'}
# 89635 {'drama'}
# ======================
# 8113 {'drama'}
# 92676 {'bdr', 'drama'}
# ======================
# 8113 {'drama'}
# 94186 {'drama'}
# ======================
# 8113 {'drama'}
# 105709 {'drama'}
# ======================
# 8113 {'drama'}
# 109798 {'comedi', 'drama'}
# ======================
# 8113 {'drama'}
# 112458 {'revolut', 'drama'}
# ======================
# 8113 {'drama'}
# 115463 {'drama'}
# ======================
# 8113 {'drama'}
# 116241 {'based on play or mus', 'drama'}
# ======================
# 8113 {'drama'}
# 116531 {'music', 'drama'}
# ======================
# 8113 {'drama'}
# 117981 {'london england', 'drama'}
# ======================
# 8113 {'drama'}
# 118576 {'sibling relationship', 'drama'}
# ======================
# 8113 {'drama'}
# 121233 {'drama'}
# ======================
# 8113 {'drama'}
# 122329 {'woman director', 'drama'}
# ======================
# 8113 {'drama'}
# 123675 {'family relationship', 'drama'}
# ======================
# 8113 {'drama'}
# 123713 {'adventur', 'drama'}
# ======================
# 8113 {'drama'}
# 123755 {'drama'}
# ======================
# 8113 {'drama'}
# 124366 {'bdr', 'drama'}
# ======================
# 8113 {'drama'}
# 124799 {'woman director', 'drama'}
# ======================
# 8113 {'drama'}
# 129270 {'betray', 'drama'}
# ======================
# 8113 {'drama'}
# 130612 {'sport', 'drama'}
# ======================
# 8113 {'drama'}
# 131808 {'drama'}
# ======================
# 8113 {'drama'}
# 132892 {'drama'}
# ======================
# 8113 {'drama'}
# 133589 {'drama'}
# ======================
# 8113 {'drama'}
# 134160 {'thriller', 'drama'}
# ======================
# 8113 {'drama'}
# 134385 {'drama'}
# ======================
# 8113 {'drama'}
# 137170 {'drama'}
# ======================
# 8113 {'drama'}
# 137443 {'mysteri', 'drama'}
# ======================
# 8113 {'drama'}
# 138676 {'gambl', 'drama'}
# ======================
# 8113 {'drama'}
# 139893 {'fashion', 'drama'}
# ======================
# 8113 {'drama'}
# 141002 {'drama'}
# ======================
# 8113 {'drama'}
# 141664 {'war', 'drama'}
# ======================
# 8113 {'drama'}
# 142192 {'drama'}
# ======================
# 8113 {'drama'}
# 142681 {'bdr', 'drama'}
# ======================
# 8113 {'drama'}
# 142967 {'based on novel or book', 'drama'}
# ======================
# 8113 {'drama'}
# 143745 {'italian', 'drama'}
# ======================
# 8113 {'drama'}
# 143925 {'drama'}
# ======================
# 8113 {'drama'}
# 147400 {'drama'}
# ======================
# 8113 {'drama'}
# 147448 {'drama'}
# ======================
# 8113 {'drama'}
# 147811 {'new world pictur', 'drama'}
# ======================
# 8113 {'drama'}
# 147853 {'mountain', 'drama'}
# ======================
# 8113 {'drama'}
# 150671 {'romanc', 'drama'}
# ======================
# 8113 {'drama'}
# 151036 {'criterion', 'drama'}
# ======================
# 8113 {'drama'}
# 151149 {'drama'}
# ======================
# 8113 {'drama'}
# 152192 {'drama'}
# ======================
# 8113 {'drama'}
# 152633 {'woman director', 'drama'}
# ======================
# 8113 {'drama'}
# 153158 {'drama'}
# ======================
# 8113 {'drama'}
# 153658 {'drama'}
# ======================
# 8113 {'drama'}
# 153921 {'drama'}
# ======================
# 8113 {'drama'}
# 156714 {'drama'}
# ======================
# 8113 {'drama'}
# 156986 {'insan', 'drama'}
# ======================
# 8113 {'drama'}
# 159445 {'biographi', 'drama'}
# ======================
# 8113 {'drama'}
# 160836 {'drama'}
# ======================
# 8113 {'drama'}
# 160900 {'greed', 'drama'}
# ======================
# 8113 {'drama'}
# 160928 {'murder', 'drama'}
# ======================
# 8113 {'drama'}
# 162258 {'comedi', 'drama'}
# ======================
# 8113 {'drama'}
# 163661 {'drama'}
# ======================
# 8113 {'drama'}
# 164095 {'drama'}
# ======================
# 8113 {'drama'}
# 164528 {'woman director', 'drama'}
# ======================
# 8113 {'drama'}
# 166336 {'spoof', 'drama'}
# ======================
# 8113 {'drama'}
# 167540 {'woman director', 'drama'}
# ======================
# 8113 {'drama'}
# 168914 {'coming of ag', 'drama'}
# ======================
# 8113 {'drama'}
# 170199 {'war', 'drama'}
# ======================
# 8113 {'drama'}
# 170541 {'biographi', 'drama'}
# ======================
# 8113 {'drama'}
# 173453 {'drama'}
# ======================
# 8113 {'drama'}
# 173479 {'romantic comedi', 'drama'}
# ======================
# 8113 {'drama'}
# 177341 {'road movi', 'drama'}
# ======================
# 8113 {'drama'}
# 178067 {'drama'}
# ======================
# 8113 {'drama'}
# 178553 {'drama'}
# ======================
# 8113 {'drama'}
# 180121 {'inspir', 'drama'}
# ======================
# 8113 {'drama'}
# 180571 {'polit', 'drama'}
# ======================
# 8113 {'drama'}
# 180919 {'famili', 'drama'}
# ======================
# 8113 {'drama'}
# 181987 {'romanc', 'drama'}
# ======================
# 8113 {'drama'}
# 182941 {'thoughtprovok', 'drama'}
# ======================
# 8113 {'drama'}
# 184205 {'thriller', 'drama'}
# ======================
# 8113 {'drama'}
# 184241 {'drama', 'write'}
# ======================
# 8113 {'drama'}
# 184483 {'woman director', 'drama'}
# ======================
# 8113 {'drama'}
# 187037 {'drama'}
# ======================
# 8113 {'drama'}
# 187315 {'comedi', 'drama'}
# ======================
# 8113 {'drama'}
# 187705 {'drama'}
# ======================
# 8113 {'drama'}
# 188445 {'famili', 'drama'}
# ======================
# 8113 {'drama'}
# 188521 {'documentari', 'drama'}
# ======================
# 8113 {'drama'}
# 190055 {'romanc', 'drama'}
# ======================
# 8113 {'drama'}
# 193679 {'japanes', 'drama'}
# ======================
# 8113 {'drama'}
# 176529 {'drama', 'based on a book'}
# ======================
# 8113 {'drama'}
# 128727 {'drama'}
# ======================
# 8113 {'drama'}
# 143876 {'lesbian', 'drama'}
# ======================
# 8113 {'drama'}
# 143713 {'drama'}
# ======================
# 8113 {'drama'}
# 185793 {'manipul', 'drama'}
# ======================
# 8113 {'drama'}
# 111762 {'romanc', 'drama'}
# ======================
# 8113 {'drama'}
# 163512 {'drama'}
# ======================
# 8113 {'drama'}
# 120779 {'drama'}
# ======================
# 8113 {'drama'}
# 164645 {'famili', 'drama'}
# ======================
# 8113 {'drama'}
# 91902 {'famili', 'drama'}
# ======================
# 8113 {'drama'}
# 189417 {'vietnam', 'drama'}
# ======================
# 8113 {'drama'}
# 140271 {'drama'}
# ======================
# 8113 {'drama'}
# 86721 {'drama'}
# ======================
# 8113 {'drama'}
# 31628 {'japan', 'drama'}
# ======================
# 8113 {'drama'}
# 26744 {'clv', 'drama'}
# ======================
# 8113 {'drama'}
# 200598 {'prospect pref', 'drama'}
# ======================
# 8113 {'drama'}
# 133804 {'drama'}
# ======================
# 8113 {'drama'}
# 96054 {'drama'}
# ======================
# 8113 {'drama'}
# 134356 {'foreign', 'drama'}
# ======================
# 8113 {'drama'}
# 189937 {'famili', 'drama'}
# ======================
# 8113 {'drama'}
# 166862 {'comedi', 'drama'}
# ======================
# 8113 {'drama'}
# 181105 {'horror', 'drama'}
# ======================
# 8113 {'drama'}
# 187889 {'drama'}
# ======================
# 8113 {'drama'}
# 187903 {'action', 'drama'}
# ======================
# 8113 {'drama'}
# 187919 {'romanc', 'drama'}
# ======================
# 8113 {'drama'}
# 187931 {'romanc', 'drama'}
# ======================
# 8113 {'drama'}
# 187933 {'romanc', 'drama'}
# ======================
# 8113 {'drama'}
# 132450 {'drama'}
# ======================
# 8113 {'drama'}
# 117498 {'drama'}
# ======================
# 8113 {'drama'}
# 135873 {'drama'}
# ======================
# 8113 {'drama'}
# 147994 {'music', 'drama'}
# ======================
# 8113 {'drama'}
# 170997 {'friendship', 'drama'}
# ======================
# 8113 {'drama'}
# 197225 {'drama'}
# ======================
# 8113 {'drama'}
# 135492 {'comedi', 'drama'}
# ======================
# 8113 {'drama'}
# 128971 {'drama'}
# ======================
# 8113 {'drama'}
# 136507 {'drama'}
# ======================
# 8113 {'drama'}
# 155627 {'thriller', 'drama'}
# ======================
# 8113 {'drama'}
# 184119 {'action', 'drama'}
# ======================
# 8113 {'drama'}
# 186419 {'romanc', 'drama'}
# ======================
# 8113 {'drama'}
# 65381 {'western', 'drama'}
# ======================
# 8113 {'drama'}
# 134963 {'comedi', 'drama'}
# ======================
# 8113 {'drama'}
# 139877 {'tens', 'drama'}
# ======================
# 8113 {'drama'}
# 141006 {'drug', 'drama'}
# ======================
# 8113 {'drama'}
# 41815 {'drama'}
# ======================
# 8113 {'drama'}
# 185569 {'action', 'drama'}
# ======================
# 8113 {'drama'}
# 99807 {'romanc', 'drama'}
# ======================
# 8113 {'drama'}
# 161638 {'war', 'drama'}
# ======================
# 8113 {'drama'}
# 97042 {'stori', 'drama'}
# ======================
# 8113 {'drama'}
# 160420 {'script', 'drama'}
# ======================
# 8113 {'drama'}
# 654 {'german', 'drama'}
# ======================
# 8113 {'drama'}
# 167466 {'music', 'drama'}
# ======================
# 8139 {'witch', 'fantasi', 'magic', 'fantasy world', 'wizard'}
# 120416 {'fantasi', 'magic', 'witch'}
# ======================
# 8139 {'witch', 'fantasi', 'magic', 'fantasy world', 'wizard'}
# 171089 {'fantasy world', 'wizard', 'magic'}
# ======================
# 8139 {'witch', 'fantasi', 'magic', 'fantasy world', 'wizard'}
# 43838 {'harry pott', 'witch', 'so bad its good', 'fantasi', 'magic', 'betamax', 'wizard'}
# ======================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-010cac2b434b> in <module>()
#       1 for index, user_row in users_profile.iterrows():
#       2   for index, movie_row in movies_profile.iterrows():
# ----> 3     if jaccard(user_row['ttag_u'], movie_row['ttag_g']) >= 0.5:
#       4       print(user_row['userId'], user_row['ttag_u'])
#       5       print(movie_row['movieId'], movie_row['ttag_g'])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3352         """
#    3353         if method is None:
# -> 3354             if tolerance is not None:
#    3355                 raise ValueError(
#    3356                     "tolerance argument only valid if using pad, "
#
# KeyboardInterrupt:

# %% [markdown]
# ## Recomendation for chosen user

# %%
def recomendation_for_user(user, treshold):
  f = list(df[df['userId']==user]['movieId'].unique())
  for index, movie_row in movies_profile.iterrows():
    if jaccard(users_profile.loc[users_profile['userId']==user, 'ttag_u'].iloc[0], movie_row['ttag_g']) >= treshold and f !=movie_row['movieId']:
      print(movie_row['movieId'], movie_row['ttag_g'])
      print("======================")

# %% [markdown]
# User with threshold

# %%
recomendation_for_user(19, 0.5)

# %%
recomendation_for_user(91, 0.2)
# Out:
# 356 {'vietnam war', 'histori', 'intellig', 'feel good movi', 'reflect', 'oscar best supporting actor', 'feelgood', 'plot', 'goofi', 'slow', 'comedi', 'new york c', 'good act', 'unpredict', 'mental il', 'clich', 'forest', 'great act', 'good dialogu', 'happy end', 'bechdel testfail', 'drama', 'inspir', 'whimsic', 'bulli', 'gay', 'footbal', 'uplift', 'fun', 'dark comedi', 'memasas movi', 'tumeys dvd', 'biopic', 'vietnam', 'long', 'sweet', 'sentiment', 'heartwarm', 'funni', 'disappoint', 'box', 'act', 'based on novel or book', 'flashback', 'philosoph', 'thoughtprovok', 'poignant', 'based on book', 'biographi', 'action', 'watch', 'friendship', '1970', 'origin', 'oscar best pictur', 'los angel', 'nostalgia', 'beauti', 'interest', 'psycholog', 'steven spielberg', 'famili', 'overr', 'book', 'militari', 'underdog', 'clv', 'family relationship', 'good soundtrack', 'oscar best actor', 'masterpiec', 'humor', 'excellent script', 'cute', 'war', 'emot', 'special effect', 'storytel', '1960', 'silli', 'oscar winn', 'seen at the cinema', 'disabl', 'dvdvideo', 'usa', 'sexual', 'bittersweet', 'sad', 'cult film', 'great perform', 'quotabl', 'strang', 'intens', 'own', 'nuditi', 'polit', 'coming of ag', 'bore', 'oscar nominee best pictur', 'nostalg', 'bdvideo', 'creativ', 'love', 'cheesi', 'highly quot', 'pg13', 'fantasi', 'multiple storylin', 'adapted frombook', 'epic', 'stupid', 'bad act', 'too long', '1950', 'satir', 'dvd', 'based on a book', 'seen more than onc', 'period piec', 'love stori', 'touch', 'quirki', 'witti', 'oscar best effects  visual effect', 'great soundtrack', 'realist', 'clever', 'cult', 'histor', 'parent child relationship', 'afi 100', 'oscar best direct', 'adventur', 'classic', 'tom hank', 'thought provok', 'social commentari', 'antholog', 'justic', 'stori', '1980', 'cancer', 'biograph', 'meaning of lif', 'imdb top 250', 'soundtrack', 'narrat', 'romanc'}
# ======================

# %%
recomendation_for_user(3, 0.5)
# Out:
# 126579 {'scifi'}
# ======================
# 5722 {'classic'}
# ======================
# 81736 {'classic'}
# ======================

# %%
list(df[df['userId']==3]['movieId'].unique())
# Out:
# [260]
